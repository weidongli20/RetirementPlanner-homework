# %% [markdown]
# # Budget Analysis
#
# ---
#
# ## Environment Setup

# %%
# Initial Imports
import os
import plaid
import requests
import datetime
import json
import pandas as pd
from dotenv import load_dotenv

# %matplotlib inline

# %%
# Helper functions

def pretty_print_response(response):
    """
    This function formats a JSON file to pretty printing it in the screen.
    """
    print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Set environment variables from the .env file
load_dotenv()
# Out:
# True

# %%
# Extract API keys from environment variables
PLAID_CLIENT_ID = os.getenv("PLAID_CLIENT_ID")
PLAID_SBX_SECRET = os.getenv("PLAID_SBX_SECRET_KEY")
PLAID_PUBLIC_KEY = os.getenv("PLAID_PUBLIC_KEY")

# %%
PLAID_CLIENT_ID
# Out:
# '5efce55111b5dd00122090a5'

# %%
PLAID_SBX_SECRET
# Out:
# '84811e856200a71c3b5e207f122559'

# %%
PLAID_PUBLIC_KEY
# Out:
# 'e5a0a869690c1eded5c8d5209c08a7'

# %% [markdown]
# ---
#
# ## Plaid Access Token
#
# In this section, you will use the `plaid-python` API to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
#
# 1. Create a client to connect to plaid
#
# 2. Use the client to generate a public token and request the following items: ['transactions', 'income', 'assets']
#
# 3. Exchange the public token for an access token
#
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
# Create the client object
client = plaid.Client(client_id = PLAID_CLIENT_ID,
                      secret = PLAID_SBX_SECRET,
                      public_key = PLAID_PUBLIC_KEY,
                      environment = 'sandbox')

# %%
# Set the institution id
INSTITUTION_ID = "ins_109508"

# %% [markdown]
# ### 2. Generate a public token

# %%
# Create the public token
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID,
                                                        ['transactions', 'income', 'assets'])
# Print the public token
pretty_print_response(create_tkn_response)
# Out:
# {
#     "public_token": "public-sandbox-7c352d42-caea-4e76-9efb-fbc31507b4db",
#     "request_id": "NFmyAGJkphk0XV8"
# }

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# Retrieve the access token
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])

# Print the access toke
pretty_print_response(exchange_response)
# Out:
# {
#     "access_token": "access-sandbox-e9242bc6-bc15-4f9c-a9e0-a8677e7ffef7",
#     "item_id": "kBKA9zJnEMcGxN3rb5e3i97G7E6yA1IWQJzwe",
#     "request_id": "PUQ1OaMrOjRh2FX"
# }

# %%
# Store the access token in a Python variable
access_token = exchange_response['access_token']

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# Retrieve accounts
accounts = client.Accounts.get(access_token)
# Print accounts
pretty_print_response(accounts)
# Out:
# {
#     "accounts": [
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "balances": {
#                 "available": 100,
#                 "current": 110,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "0000",
#             "name": "Plaid Checking",
#             "official_name": "Plaid Gold Standard 0% Interest Checking",
#             "subtype": "checking",
#             "type": "depository"
#         },
#         {
#             "account_id": "oa3yqdxlE1hLmqnVJdbncj9dbewdMXCR5bnP5",
#             "balances": {
#                 "available": 200,
#                 "current": 210,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "1111",
#             "name": "Plaid Saving",
#             "official_name": "Plaid Silver Standard 0.1% Interest Saving",
#             "subtype": "savings",
#             "type": "depository"
#         },
#         {
#             "account_id": "gqy7nlvE9MfGA5Qp1lwQiGeoVxgo9AHgR5QG8",
#             "balances": {
#                 "available": null,
#                 "current": 1000,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "2222",
#             "name": "Plaid CD",
#             "official_name": "Plaid Bronze Standard 0.2% Interest CD",
#             "subtype": "cd",
#             "type": "depository"
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "balances": {
#                 "available": null,
#                 "current": 410,
#                 "iso_currency_code": "USD",
#                 "limit": 2000,
#                 "unofficial_currency_code": null
#             },
#             "mask": "3333",
#             "name": "Plaid Credit Card",
#             "official_name": "Plaid Diamond 12.5% APR Interest Credit Card",
#             "subtype": "credit card",
#             "type": "credit"
#         },
#         {
#             "account_id": "EXy3mla8eVcJAD3zZdj3CajByR8BmJHXemPMq",
#             "balances": {
#                 "available": 43200,
#                 "current": 43200,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "4444",
#             "name": "Plaid Money Market",
#             "official_name": "Plaid Platinum Standard 1.85% Interest Money Market",
#             "subtype": "money market",
#             "type": "depository"
#         },
#         {
#             "account_id": "WnQkjqKaNXiJQoyreldyCKXAB9kAVEHlyj75G",
#             "balances": {
#                 "available": null,
#                 "current": 320.76,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "5555",
#             "name": "Plaid IRA",
#             "official_name": null,
#             "subtype": "ira",
#             "type": "investment"
#         },
#         {
#             "account_id": "AXGKAyqLNwcEJNDqgLaDcQgw8nvwlBh1J5lkX",
#             "balances": {
#                 "available": null,
#                 "current": 23631.9805,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "6666",
#             "name": "Plaid 401k",
#             "official_name": null,
#             "subtype": "401k",
#             "type": "investment"
#         },
#         {
#             "account_id": "GXld9KjWZncalLvokyevc3Xa8BbaMgU1xoXLl",
#             "balances": {
#                 "available": null,
#                 "current": 65262,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "7777",
#             "name": "Plaid Student Loan",
#             "official_name": null,
#             "subtype": "student",
#             "type": "loan"
#         },
#         {
#             "account_id": "ndkAlxByERfW4le3BNbeCP9jGqxjemi6VQNXo",
#             "balances": {
#                 "available": null,
#                 "current": 56302.06,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "8888",
#             "name": "Plaid Mortgage",
#             "official_name": null,
#             "subtype": "mortgage",
#             "type": "loan"
#         }
#     ],
#     "item": {
#         "available_products": [
#             "auth",
#             "balance",
#             "credit_details",
#             "identity",
#             "investments",
#             "liabilities"
#         ],
#         "billed_products": [
#             "assets",
#             "income",
#             "transactions"
#         ],
#         "consent_expiration_time": null,
#         "error": null,
#         "institution_id": "ins_109508",
#         "item_id": "kBKA9zJnEMcGxN3rb5e3i97G7E6yA1IWQJzwe",
#         "webhook": ""
#     },
#     "request_id": "Yn9v8cieC7zVzhw"
# }

# %% [markdown]
# ---
#
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
#
# 2. Print the categories for each transaction type
#
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
#
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# Set the start and end date 90 days from today
start_date = "{:%Y-%m-%d}".format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = "{:%Y-%m-%d}".format(datetime.datetime.now())
# Retrieve the transactions for the last 90 days
transactions_response = client.Transactions.get(access_token, start_date, end_date)
# Print the transactions
pretty_print_response(transactions_response)
# Out:
# {
#     "accounts": [
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "balances": {
#                 "available": 100,
#                 "current": 110,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "0000",
#             "name": "Plaid Checking",
#             "official_name": "Plaid Gold Standard 0% Interest Checking",
#             "subtype": "checking",
#             "type": "depository"
#         },
#         {
#             "account_id": "oa3yqdxlE1hLmqnVJdbncj9dbewdMXCR5bnP5",
#             "balances": {
#                 "available": 200,
#                 "current": 210,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "1111",
#             "name": "Plaid Saving",
#             "official_name": "Plaid Silver Standard 0.1% Interest Saving",
#             "subtype": "savings",
#             "type": "depository"
#         },
#         {
#             "account_id": "gqy7nlvE9MfGA5Qp1lwQiGeoVxgo9AHgR5QG8",
#             "balances": {
#                 "available": null,
#                 "current": 1000,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "2222",
#             "name": "Plaid CD",
#             "official_name": "Plaid Bronze Standard 0.2% Interest CD",
#             "subtype": "cd",
#             "type": "depository"
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "balances": {
#                 "available": null,
#                 "current": 410,
#                 "iso_currency_code": "USD",
#                 "limit": 2000,
#                 "unofficial_currency_code": null
#             },
#             "mask": "3333",
#             "name": "Plaid Credit Card",
#             "official_name": "Plaid Diamond 12.5% APR Interest Credit Card",
#             "subtype": "credit card",
#             "type": "credit"
#         },
#         {
#             "account_id": "EXy3mla8eVcJAD3zZdj3CajByR8BmJHXemPMq",
#             "balances": {
#                 "available": 43200,
#                 "current": 43200,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "4444",
#             "name": "Plaid Money Market",
#             "official_name": "Plaid Platinum Standard 1.85% Interest Money Market",
#             "subtype": "money market",
#             "type": "depository"
#         },
#         {
#             "account_id": "WnQkjqKaNXiJQoyreldyCKXAB9kAVEHlyj75G",
#             "balances": {
#                 "available": null,
#                 "current": 320.76,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "5555",
#             "name": "Plaid IRA",
#             "official_name": null,
#             "subtype": "ira",
#             "type": "investment"
#         },
#         {
#             "account_id": "AXGKAyqLNwcEJNDqgLaDcQgw8nvwlBh1J5lkX",
#             "balances": {
#                 "available": null,
#                 "current": 23631.9805,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "6666",
#             "name": "Plaid 401k",
#             "official_name": null,
#             "subtype": "401k",
#             "type": "investment"
#         },
#         {
#             "account_id": "GXld9KjWZncalLvokyevc3Xa8BbaMgU1xoXLl",
#             "balances": {
#                 "available": null,
#                 "current": 65262,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "7777",
#             "name": "Plaid Student Loan",
#             "official_name": null,
#             "subtype": "student",
#             "type": "loan"
#         },
#         {
#             "account_id": "ndkAlxByERfW4le3BNbeCP9jGqxjemi6VQNXo",
#             "balances": {
#                 "available": null,
#                 "current": 56302.06,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "8888",
#             "name": "Plaid Mortgage",
#             "official_name": null,
#             "subtype": "mortgage",
#             "type": "loan"
#         }
#     ],
#     "item": {
#         "available_products": [
#             "auth",
#             "balance",
#             "credit_details",
#             "identity",
#             "investments",
#             "liabilities"
#         ],
#         "billed_products": [
#             "assets",
#             "income",
#             "transactions"
#         ],
#         "consent_expiration_time": null,
#         "error": null,
#         "institution_id": "ins_109508",
#         "item_id": "kBKA9zJnEMcGxN3rb5e3i97G7E6yA1IWQJzwe",
#         "webhook": ""
#     },
#     "request_id": "oh3SIk1gktNKHZg",
#     "total_transactions": 48,
#     "transactions": [
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-06-29",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "United Airlines",
#             "name": "United Airlines",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "NXxPzaAlK8cnxDkNgvokSkLwm85zbafWgBKKK",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 6.33,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-06-27",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Uber",
#             "name": "Uber 072515 SF**POOL**",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "KXzPq3pbkAcvzDRPn81Rh6GQbg5jVKcVLWNAd",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-06-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Tectra Inc",
#             "name": "Tectra Inc",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "PVa73NmKzkueaDxNrBnxuvWgGA5n4af79BvvA",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 2078.5,
#             "authorized_date": null,
#             "category": [
#                 "Payment"
#             ],
#             "category_id": "16000000",
#             "date": "2020-06-23",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "AUTOMATIC PAYMENT - THANK",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "enkwAebgEMinJB81bxo8SrWZNyq8xbfLzRkkB",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-06-23",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "KFC",
#             "name": "KFC",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "7kMXZy84qRF5gkMGNa8Mtaey5g8LdAIgmAppb",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Shops",
#                 "Sporting Goods"
#             ],
#             "category_id": "19046000",
#             "date": "2020-06-23",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Madison Bicycle Shop",
#             "name": "Madison Bicycle Shop",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "jzq7yrwGELfde4zV3jbzHGzDqlmLveI1BzAAR",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "oa3yqdxlE1hLmqnVJdbncj9dbewdMXCR5bnP5",
#             "account_owner": null,
#             "amount": 25,
#             "authorized_date": null,
#             "category": [
#                 "Payment",
#                 "Credit Card"
#             ],
#             "category_id": "16001000",
#             "date": "2020-06-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "CREDIT CARD 3333 PAYMENT *//",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "dbnZW7GoEMFEnzgDpmvgcG6148wmNXIZm5aax",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 5.4,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-06-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Uber",
#             "name": "Uber 063015 SF**POOL**",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "rPawzNjrE7fyjzBlqp7BFQlZ8KJV3mslnqM6K",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "EXy3mla8eVcJAD3zZdj3CajByR8BmJHXemPMq",
#             "account_owner": null,
#             "amount": 5850,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Debit"
#             ],
#             "category_id": "21006000",
#             "date": "2020-06-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "ACH Electronic CreditGUSTO PAY 123456",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": "ACH",
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "ZR1BQzdP7EFEvdR3J5nRcdWJl4pEm5ugNAlly",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "gqy7nlvE9MfGA5Qp1lwQiGeoVxgo9AHgR5QG8",
#             "account_owner": null,
#             "amount": 1000,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Deposit"
#             ],
#             "category_id": "21007000",
#             "date": "2020-06-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "CD DEPOSIT .INITIAL.",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "4meZ7yMxLnuGZRbMJB8biE8G9ZWx6qIdZNMMA",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 78.5,
#             "authorized_date": null,
#             "category": [
#                 "Recreation",
#                 "Gyms and Fitness Centers"
#             ],
#             "category_id": "17018000",
#             "date": "2020-06-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Touchstone",
#             "name": "Touchstone Climbing",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "Qy4ZxP9rBpcgvLaNG1nau3J7EqDWXlspJ4eem",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": -500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-06-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "United Airlines",
#             "name": "United Airlines",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "zLZzPonNKluzVP9Ro1X9S987E4lXRBiozJmmx",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 12,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-06-11",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": "3322"
#             },
#             "merchant_name": "McDonald's",
#             "name": "McDonald's",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "BXnkGyrpPLcAMPVlQk4VCb4l67L1kqcwQ6jjd",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 4.33,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Coffee Shop"
#             ],
#             "category_id": "13005043",
#             "date": "2020-06-11",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Starbucks",
#             "name": "Starbucks",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "357JjkQ31nuGXk7yZl87iJogGXQb97tqBKRRz",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 89.4,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-06-10",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Sparkfun",
#             "name": "SparkFun",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "xMeK4kEalDFxJ4d3Q9mdCnEqk9Wz8AcnqpBBq",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "oa3yqdxlE1hLmqnVJdbncj9dbewdMXCR5bnP5",
#             "account_owner": null,
#             "amount": -4.22,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Credit"
#             ],
#             "category_id": "21005000",
#             "date": "2020-06-09",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "INTRST PYMNT",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "aDW7gNo1p6clWqwyaB5wtdvmxeJrQVu7zl33L",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-05-30",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "United Airlines",
#             "name": "United Airlines",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "XJZr7Kz4PbtVZg9XKem9cvLkEV46ALid3zEa7",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 6.33,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-05-28",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Uber",
#             "name": "Uber 072515 SF**POOL**",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "RnNGdjRz3wi8N19bGWr9t4bno8z5kbcRBr4qA",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-05-25",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Tectra Inc",
#             "name": "Tectra Inc",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "6DZvQyoalncX6oWjyV8WtwkvdoxbzktgyM35M",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 2078.5,
#             "authorized_date": null,
#             "category": [
#                 "Payment"
#             ],
#             "category_id": "16000000",
#             "date": "2020-05-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "AUTOMATIC PAYMENT - THANK",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "RnNGdjRz3wi8N19bGWr9t4bno8z5kbcRBr4E1",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-05-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "KFC",
#             "name": "KFC",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "vQjldepxXgtAedxzDa7xCwdnZyXb4dtWE4RdV",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Shops",
#                 "Sporting Goods"
#             ],
#             "category_id": "19046000",
#             "date": "2020-05-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Madison Bicycle Shop",
#             "name": "Madison Bicycle Shop",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "9XL61yGPrRcRgr4jE6q4tpq5EBDAPqCR5bD6B",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "oa3yqdxlE1hLmqnVJdbncj9dbewdMXCR5bnP5",
#             "account_owner": null,
#             "amount": 25,
#             "authorized_date": null,
#             "category": [
#                 "Payment",
#                 "Credit Card"
#             ],
#             "category_id": "16001000",
#             "date": "2020-05-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "CREDIT CARD 3333 PAYMENT *//",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "oa3yqdxlE1hLmqnVJdbncj9kwqWbB9tRzxyMQ",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 5.4,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-05-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Uber",
#             "name": "Uber 063015 SF**POOL**",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "vQjldepxXgtAedxzDa7xCwdnZyXb4dtWE4RKR",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "EXy3mla8eVcJAD3zZdj3CajByR8BmJHXemPMq",
#             "account_owner": null,
#             "amount": 5850,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Debit"
#             ],
#             "category_id": "21006000",
#             "date": "2020-05-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "ACH Electronic CreditGUSTO PAY 123456",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": "ACH",
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "Qy4ZxP9rBpcgvLaNG1nau3JvXrw9PJIpJ4eng",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "gqy7nlvE9MfGA5Qp1lwQiGeoVxgo9AHgR5QG8",
#             "account_owner": null,
#             "amount": 1000,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Deposit"
#             ],
#             "category_id": "21007000",
#             "date": "2020-05-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "CD DEPOSIT .INITIAL.",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "qkdAr4NKwJFXJrMQqLNMtEjNgloevjudZAMmo",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 78.5,
#             "authorized_date": null,
#             "category": [
#                 "Recreation",
#                 "Gyms and Fitness Centers"
#             ],
#             "category_id": "17018000",
#             "date": "2020-05-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Touchstone",
#             "name": "Touchstone Climbing",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "y1QrNJA4qkFWnN4xZVp4CVobDBRPpouylLABg",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": -500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-05-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "United Airlines",
#             "name": "United Airlines",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "9XL61yGPrRcRgr4jE6q4tpq5EBDAPqCR5bDvQ",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 12,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-05-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": "3322"
#             },
#             "merchant_name": "McDonald's",
#             "name": "McDonald's",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "mxzAR3rmyMfVaRpQ5mbpcG8Mvw76K8cLWwJon",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 4.33,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Coffee Shop"
#             ],
#             "category_id": "13005043",
#             "date": "2020-05-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Starbucks",
#             "name": "Starbucks",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
# ...
#             "transaction_code": null,
#             "transaction_id": "GXld9KjWZncalLvokyevc3X5bnl8yXI1Qr3dA",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Shops",
#                 "Sporting Goods"
#             ],
#             "category_id": "19046000",
#             "date": "2020-04-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Madison Bicycle Shop",
#             "name": "Madison Bicycle Shop",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "AXGKAyqLNwcEJNDqgLaDcQgNvxJ8agU1dKPm4",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "oa3yqdxlE1hLmqnVJdbncj9dbewdMXCR5bnP5",
#             "account_owner": null,
#             "amount": 25,
#             "authorized_date": null,
#             "category": [
#                 "Payment",
#                 "Credit Card"
#             ],
#             "category_id": "16001000",
#             "date": "2020-04-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "CREDIT CARD 3333 PAYMENT *//",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "LXBPKxgmlpcZBk8PR3L8caEyqZBkNEHPRvaQE",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 5.4,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-04-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Uber",
#             "name": "Uber 063015 SF**POOL**",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "GXld9KjWZncalLvokyevc3X5bnl8yXI1Qr3pm",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "EXy3mla8eVcJAD3zZdj3CajByR8BmJHXemPMq",
#             "account_owner": null,
#             "amount": 5850,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Debit"
#             ],
#             "category_id": "21006000",
#             "date": "2020-04-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "ACH Electronic CreditGUSTO PAY 123456",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": "ACH",
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "enkwAebgEMinJB81bxo8SrW7xkAdKWiLzRkXg",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "gqy7nlvE9MfGA5Qp1lwQiGeoVxgo9AHgR5QG8",
#             "account_owner": null,
#             "amount": 1000,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Deposit"
#             ],
#             "category_id": "21007000",
#             "date": "2020-04-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "CD DEPOSIT .INITIAL.",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "l3rAvBqbEmFxdP3z5L93C4BEykAlzBcZkG7wr",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "8X1ZMyWNKJcZ9KbmQjlbcbXJdL4JkrCwp8VRo",
#             "account_owner": null,
#             "amount": 78.5,
#             "authorized_date": null,
#             "category": [
#                 "Recreation",
#                 "Gyms and Fitness Centers"
#             ],
#             "category_id": "17018000",
#             "date": "2020-04-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Touchstone",
#             "name": "Touchstone Climbing",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "WnQkjqKaNXiJQoyreldyCKXMkJLBwXtlDAEV6",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": -500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-04-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "United Airlines",
#             "name": "United Airlines",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "AXGKAyqLNwcEJNDqgLaDcQgNvxJ8agU1dKPpg",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 12,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-04-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": "3322"
#             },
#             "merchant_name": "McDonald's",
#             "name": "McDonald's",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "EXy3mla8eVcJAD3zZdj3Cajx84nygjHX1vlyW",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 4.33,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Coffee Shop"
#             ],
#             "category_id": "13005043",
#             "date": "2020-04-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Starbucks",
#             "name": "Starbucks",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "WnQkjqKaNXiJQoyreldyCKXMkJLBwXtlDAERL",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "p4xAKkaqwMCbAKZQ9nRZSyXZxMDZrpTLjzNql",
#             "account_owner": null,
#             "amount": 89.4,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-04-11",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": "Sparkfun",
#             "name": "SparkFun",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "8X1ZMyWNKJcZ9KbmQjlbcbXq4g6dKXiwG4mnk",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "oa3yqdxlE1hLmqnVJdbncj9dbewdMXCR5bnP5",
#             "account_owner": null,
#             "amount": -4.22,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Credit"
#             ],
#             "category_id": "21005000",
#             "date": "2020-04-10",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "merchant_name": null,
#             "name": "INTRST PYMNT",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "18kWN7PzZ6FlLR4BPKQ4tAadzvnXpac5xLoKo",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         }
#     ]
# }

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# Create a for-loop to print the categories for each transaction
for transactions in transactions_response['transactions']:
    print(json.dumps(transactions['category']))
# Out:
# ["Travel", "Airlines and Aviation Services"]
# ["Travel", "Taxi"]
# ["Food and Drink", "Restaurants"]
# ["Payment"]
# ["Food and Drink", "Restaurants", "Fast Food"]
# ["Shops", "Sporting Goods"]
# ["Payment", "Credit Card"]
# ["Travel", "Taxi"]
# ["Transfer", "Debit"]
# ["Transfer", "Deposit"]
# ["Recreation", "Gyms and Fitness Centers"]
# ["Travel", "Airlines and Aviation Services"]
# ["Food and Drink", "Restaurants", "Fast Food"]
# ["Food and Drink", "Restaurants", "Coffee Shop"]
# ["Food and Drink", "Restaurants"]
# ["Transfer", "Credit"]
# ["Travel", "Airlines and Aviation Services"]
# ["Travel", "Taxi"]
# ["Food and Drink", "Restaurants"]
# ["Payment"]
# ["Food and Drink", "Restaurants", "Fast Food"]
# ["Shops", "Sporting Goods"]
# ["Payment", "Credit Card"]
# ["Travel", "Taxi"]
# ["Transfer", "Debit"]
# ["Transfer", "Deposit"]
# ["Recreation", "Gyms and Fitness Centers"]
# ["Travel", "Airlines and Aviation Services"]
# ["Food and Drink", "Restaurants", "Fast Food"]
# ["Food and Drink", "Restaurants", "Coffee Shop"]
# ["Food and Drink", "Restaurants"]
# ["Transfer", "Credit"]
# ["Travel", "Airlines and Aviation Services"]
# ["Travel", "Taxi"]
# ["Food and Drink", "Restaurants"]
# ["Payment"]
# ["Food and Drink", "Restaurants", "Fast Food"]
# ["Shops", "Sporting Goods"]
# ["Payment", "Credit Card"]
# ["Travel", "Taxi"]
# ["Transfer", "Debit"]
# ["Transfer", "Deposit"]
# ["Recreation", "Gyms and Fitness Centers"]
# ["Travel", "Airlines and Aviation Services"]
# ["Food and Drink", "Restaurants", "Fast Food"]
# ["Food and Drink", "Restaurants", "Coffee Shop"]
# ["Food and Drink", "Restaurants"]
# ["Transfer", "Credit"]

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: `date`, `name`, `amount`, `category`.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# Define an empty DataFrame and set the columns as date, name, amount, and category
columns = ['date', 'name', 'amount', 'category']
# Retrieve all the transactions
all_transactions_df = pd.DataFrame(transactions_response['transactions'])
# Populate the transactions DataFrame with the transactions data
selected_df = all_transactions_df[columns]
# Display sample data from the DataFrame    
selected_df
# Out:
#           date                                   name   amount  \
# 0   2020-06-29                        United Airlines   500.00
# 1   2020-06-27                 Uber 072515 SF**POOL**     6.33
# 2   2020-06-24                             Tectra Inc   500.00
# 3   2020-06-23              AUTOMATIC PAYMENT - THANK  2078.50
# 4   2020-06-23                                    KFC   500.00
# 5   2020-06-23                   Madison Bicycle Shop   500.00
# 6   2020-06-14           CREDIT CARD 3333 PAYMENT *//    25.00
# 7   2020-06-14                 Uber 063015 SF**POOL**     5.40
# 8   2020-06-13  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 9   2020-06-13                   CD DEPOSIT .INITIAL.  1000.00
# 10  2020-06-12                    Touchstone Climbing    78.50
# 11  2020-06-12                        United Airlines  -500.00
# 12  2020-06-11                             McDonald's    12.00
# 13  2020-06-11                              Starbucks     4.33
# 14  2020-06-10                               SparkFun    89.40
# 15  2020-06-09                           INTRST PYMNT    -4.22
# 16  2020-05-30                        United Airlines   500.00
# 17  2020-05-28                 Uber 072515 SF**POOL**     6.33
# 18  2020-05-25                             Tectra Inc   500.00
# 19  2020-05-24              AUTOMATIC PAYMENT - THANK  2078.50
# 20  2020-05-24                                    KFC   500.00
# 21  2020-05-24                   Madison Bicycle Shop   500.00
# 22  2020-05-15           CREDIT CARD 3333 PAYMENT *//    25.00
# 23  2020-05-15                 Uber 063015 SF**POOL**     5.40
# 24  2020-05-14  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 25  2020-05-14                   CD DEPOSIT .INITIAL.  1000.00
# 26  2020-05-13                    Touchstone Climbing    78.50
# 27  2020-05-13                        United Airlines  -500.00
# 28  2020-05-12                             McDonald's    12.00
# 29  2020-05-12                              Starbucks     4.33
# 30  2020-05-11                               SparkFun    89.40
# 31  2020-05-10                           INTRST PYMNT    -4.22
# 32  2020-04-30                        United Airlines   500.00
# 33  2020-04-28                 Uber 072515 SF**POOL**     6.33
# 34  2020-04-25                             Tectra Inc   500.00
# 35  2020-04-24              AUTOMATIC PAYMENT - THANK  2078.50
# 36  2020-04-24                                    KFC   500.00
# 37  2020-04-24                   Madison Bicycle Shop   500.00
# 38  2020-04-15           CREDIT CARD 3333 PAYMENT *//    25.00
# 39  2020-04-15                 Uber 063015 SF**POOL**     5.40
# 40  2020-04-14  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 41  2020-04-14                   CD DEPOSIT .INITIAL.  1000.00
# 42  2020-04-13                    Touchstone Climbing    78.50
# 43  2020-04-13                        United Airlines  -500.00
# 44  2020-04-12                             McDonald's    12.00
# 45  2020-04-12                              Starbucks     4.33
# 46  2020-04-11                               SparkFun    89.40
# 47  2020-04-10                           INTRST PYMNT    -4.22
#
#                                       category
# 0     [Travel, Airlines and Aviation Services]
# 1                               [Travel, Taxi]
# 2                [Food and Drink, Restaurants]
# 3                                    [Payment]
# 4     [Food and Drink, Restaurants, Fast Food]
# 5                      [Shops, Sporting Goods]
# 6                       [Payment, Credit Card]
# 7                               [Travel, Taxi]
# 8                            [Transfer, Debit]
# 9                          [Transfer, Deposit]
# 10      [Recreation, Gyms and Fitness Centers]
# 11    [Travel, Airlines and Aviation Services]
# 12    [Food and Drink, Restaurants, Fast Food]
# 13  [Food and Drink, Restaurants, Coffee Shop]
# 14               [Food and Drink, Restaurants]
# 15                          [Transfer, Credit]
# 16    [Travel, Airlines and Aviation Services]
# 17                              [Travel, Taxi]
# 18               [Food and Drink, Restaurants]
# 19                                   [Payment]
# 20    [Food and Drink, Restaurants, Fast Food]
# 21                     [Shops, Sporting Goods]
# 22                      [Payment, Credit Card]
# 23                              [Travel, Taxi]
# 24                           [Transfer, Debit]
# 25                         [Transfer, Deposit]
# 26      [Recreation, Gyms and Fitness Centers]
# 27    [Travel, Airlines and Aviation Services]
# 28    [Food and Drink, Restaurants, Fast Food]
# 29  [Food and Drink, Restaurants, Coffee Shop]
# 30               [Food and Drink, Restaurants]
# 31                          [Transfer, Credit]
# 32    [Travel, Airlines and Aviation Services]
# 33                              [Travel, Taxi]
# 34               [Food and Drink, Restaurants]
# 35                                   [Payment]
# 36    [Food and Drink, Restaurants, Fast Food]
# 37                     [Shops, Sporting Goods]
# 38                      [Payment, Credit Card]
# 39                              [Travel, Taxi]
# 40                           [Transfer, Debit]
# 41                         [Transfer, Deposit]
# 42      [Recreation, Gyms and Fitness Centers]
# 43    [Travel, Airlines and Aviation Services]
# 44    [Food and Drink, Restaurants, Fast Food]
# 45  [Food and Drink, Restaurants, Coffee Shop]
# 46               [Food and Drink, Restaurants]
# 47                          [Transfer, Credit]

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# Display data types
selected_df.dtypes
# Out:
# date         object
# name         object
# amount      float64
# category     object
# dtype: object

# %%
# Make any required data type transformation
selected_df['date'] = pd.to_datetime(selected_df['date'], infer_datetime_format=True)
# Out:
# /Users/liwei2/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
selected_df
# Out:
#          date                                   name   amount  \
# 0  2020-06-29                        United Airlines   500.00
# 1  2020-06-27                 Uber 072515 SF**POOL**     6.33
# 2  2020-06-24                             Tectra Inc   500.00
# 3  2020-06-23              AUTOMATIC PAYMENT - THANK  2078.50
# 4  2020-06-23                                    KFC   500.00
# 5  2020-06-23                   Madison Bicycle Shop   500.00
# 6  2020-06-14           CREDIT CARD 3333 PAYMENT *//    25.00
# 7  2020-06-14                 Uber 063015 SF**POOL**     5.40
# 8  2020-06-13  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 9  2020-06-13                   CD DEPOSIT .INITIAL.  1000.00
# 10 2020-06-12                    Touchstone Climbing    78.50
# 11 2020-06-12                        United Airlines  -500.00
# 12 2020-06-11                             McDonald's    12.00
# 13 2020-06-11                              Starbucks     4.33
# 14 2020-06-10                               SparkFun    89.40
# 15 2020-06-09                           INTRST PYMNT    -4.22
# 16 2020-05-30                        United Airlines   500.00
# 17 2020-05-28                 Uber 072515 SF**POOL**     6.33
# 18 2020-05-25                             Tectra Inc   500.00
# 19 2020-05-24              AUTOMATIC PAYMENT - THANK  2078.50
# 20 2020-05-24                                    KFC   500.00
# 21 2020-05-24                   Madison Bicycle Shop   500.00
# 22 2020-05-15           CREDIT CARD 3333 PAYMENT *//    25.00
# 23 2020-05-15                 Uber 063015 SF**POOL**     5.40
# 24 2020-05-14  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 25 2020-05-14                   CD DEPOSIT .INITIAL.  1000.00
# 26 2020-05-13                    Touchstone Climbing    78.50
# 27 2020-05-13                        United Airlines  -500.00
# 28 2020-05-12                             McDonald's    12.00
# 29 2020-05-12                              Starbucks     4.33
# 30 2020-05-11                               SparkFun    89.40
# 31 2020-05-10                           INTRST PYMNT    -4.22
# 32 2020-04-30                        United Airlines   500.00
# 33 2020-04-28                 Uber 072515 SF**POOL**     6.33
# 34 2020-04-25                             Tectra Inc   500.00
# 35 2020-04-24              AUTOMATIC PAYMENT - THANK  2078.50
# 36 2020-04-24                                    KFC   500.00
# 37 2020-04-24                   Madison Bicycle Shop   500.00
# 38 2020-04-15           CREDIT CARD 3333 PAYMENT *//    25.00
# 39 2020-04-15                 Uber 063015 SF**POOL**     5.40
# 40 2020-04-14  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 41 2020-04-14                   CD DEPOSIT .INITIAL.  1000.00
# 42 2020-04-13                    Touchstone Climbing    78.50
# 43 2020-04-13                        United Airlines  -500.00
# 44 2020-04-12                             McDonald's    12.00
# 45 2020-04-12                              Starbucks     4.33
# 46 2020-04-11                               SparkFun    89.40
# 47 2020-04-10                           INTRST PYMNT    -4.22
#
#                                       category
# 0     [Travel, Airlines and Aviation Services]
# 1                               [Travel, Taxi]
# 2                [Food and Drink, Restaurants]
# 3                                    [Payment]
# 4     [Food and Drink, Restaurants, Fast Food]
# 5                      [Shops, Sporting Goods]
# 6                       [Payment, Credit Card]
# 7                               [Travel, Taxi]
# 8                            [Transfer, Debit]
# 9                          [Transfer, Deposit]
# 10      [Recreation, Gyms and Fitness Centers]
# 11    [Travel, Airlines and Aviation Services]
# 12    [Food and Drink, Restaurants, Fast Food]
# 13  [Food and Drink, Restaurants, Coffee Shop]
# 14               [Food and Drink, Restaurants]
# 15                          [Transfer, Credit]
# 16    [Travel, Airlines and Aviation Services]
# 17                              [Travel, Taxi]
# 18               [Food and Drink, Restaurants]
# 19                                   [Payment]
# 20    [Food and Drink, Restaurants, Fast Food]
# 21                     [Shops, Sporting Goods]
# 22                      [Payment, Credit Card]
# 23                              [Travel, Taxi]
# 24                           [Transfer, Debit]
# 25                         [Transfer, Deposit]
# 26      [Recreation, Gyms and Fitness Centers]
# 27    [Travel, Airlines and Aviation Services]
# 28    [Food and Drink, Restaurants, Fast Food]
# 29  [Food and Drink, Restaurants, Coffee Shop]
# 30               [Food and Drink, Restaurants]
# 31                          [Transfer, Credit]
# 32    [Travel, Airlines and Aviation Services]
# 33                              [Travel, Taxi]
# 34               [Food and Drink, Restaurants]
# 35                                   [Payment]
# 36    [Food and Drink, Restaurants, Fast Food]
# 37                     [Shops, Sporting Goods]
# 38                      [Payment, Credit Card]
# 39                              [Travel, Taxi]
# 40                           [Transfer, Debit]
# 41                         [Transfer, Deposit]
# 42      [Recreation, Gyms and Fitness Centers]
# 43    [Travel, Airlines and Aviation Services]
# 44    [Food and Drink, Restaurants, Fast Food]
# 45  [Food and Drink, Restaurants, Coffee Shop]
# 46               [Food and Drink, Restaurants]
# 47                          [Transfer, Credit]

# %%
# Set the date column as index
selected_df.set_index('date', inplace=True)
# Display sample data
selected_df
# Out:
#                                              name   amount  \
# date
# 2020-06-29                        United Airlines   500.00
# 2020-06-27                 Uber 072515 SF**POOL**     6.33
# 2020-06-24                             Tectra Inc   500.00
# 2020-06-23              AUTOMATIC PAYMENT - THANK  2078.50
# 2020-06-23                                    KFC   500.00
# 2020-06-23                   Madison Bicycle Shop   500.00
# 2020-06-14           CREDIT CARD 3333 PAYMENT *//    25.00
# 2020-06-14                 Uber 063015 SF**POOL**     5.40
# 2020-06-13  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 2020-06-13                   CD DEPOSIT .INITIAL.  1000.00
# 2020-06-12                    Touchstone Climbing    78.50
# 2020-06-12                        United Airlines  -500.00
# 2020-06-11                             McDonald's    12.00
# 2020-06-11                              Starbucks     4.33
# 2020-06-10                               SparkFun    89.40
# 2020-06-09                           INTRST PYMNT    -4.22
# 2020-05-30                        United Airlines   500.00
# 2020-05-28                 Uber 072515 SF**POOL**     6.33
# 2020-05-25                             Tectra Inc   500.00
# 2020-05-24              AUTOMATIC PAYMENT - THANK  2078.50
# 2020-05-24                                    KFC   500.00
# 2020-05-24                   Madison Bicycle Shop   500.00
# 2020-05-15           CREDIT CARD 3333 PAYMENT *//    25.00
# 2020-05-15                 Uber 063015 SF**POOL**     5.40
# 2020-05-14  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 2020-05-14                   CD DEPOSIT .INITIAL.  1000.00
# 2020-05-13                    Touchstone Climbing    78.50
# 2020-05-13                        United Airlines  -500.00
# 2020-05-12                             McDonald's    12.00
# 2020-05-12                              Starbucks     4.33
# 2020-05-11                               SparkFun    89.40
# 2020-05-10                           INTRST PYMNT    -4.22
# 2020-04-30                        United Airlines   500.00
# 2020-04-28                 Uber 072515 SF**POOL**     6.33
# 2020-04-25                             Tectra Inc   500.00
# 2020-04-24              AUTOMATIC PAYMENT - THANK  2078.50
# 2020-04-24                                    KFC   500.00
# 2020-04-24                   Madison Bicycle Shop   500.00
# 2020-04-15           CREDIT CARD 3333 PAYMENT *//    25.00
# 2020-04-15                 Uber 063015 SF**POOL**     5.40
# 2020-04-14  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 2020-04-14                   CD DEPOSIT .INITIAL.  1000.00
# 2020-04-13                    Touchstone Climbing    78.50
# 2020-04-13                        United Airlines  -500.00
# 2020-04-12                             McDonald's    12.00
# 2020-04-12                              Starbucks     4.33
# 2020-04-11                               SparkFun    89.40
# 2020-04-10                           INTRST PYMNT    -4.22
#
#                                               category
# date
# 2020-06-29    [Travel, Airlines and Aviation Services]
# 2020-06-27                              [Travel, Taxi]
# 2020-06-24               [Food and Drink, Restaurants]
# 2020-06-23                                   [Payment]
# 2020-06-23    [Food and Drink, Restaurants, Fast Food]
# 2020-06-23                     [Shops, Sporting Goods]
# 2020-06-14                      [Payment, Credit Card]
# 2020-06-14                              [Travel, Taxi]
# 2020-06-13                           [Transfer, Debit]
# 2020-06-13                         [Transfer, Deposit]
# 2020-06-12      [Recreation, Gyms and Fitness Centers]
# 2020-06-12    [Travel, Airlines and Aviation Services]
# 2020-06-11    [Food and Drink, Restaurants, Fast Food]
# 2020-06-11  [Food and Drink, Restaurants, Coffee Shop]
# 2020-06-10               [Food and Drink, Restaurants]
# 2020-06-09                          [Transfer, Credit]
# 2020-05-30    [Travel, Airlines and Aviation Services]
# 2020-05-28                              [Travel, Taxi]
# 2020-05-25               [Food and Drink, Restaurants]
# 2020-05-24                                   [Payment]
# 2020-05-24    [Food and Drink, Restaurants, Fast Food]
# 2020-05-24                     [Shops, Sporting Goods]
# 2020-05-15                      [Payment, Credit Card]
# 2020-05-15                              [Travel, Taxi]
# 2020-05-14                           [Transfer, Debit]
# 2020-05-14                         [Transfer, Deposit]
# 2020-05-13      [Recreation, Gyms and Fitness Centers]
# 2020-05-13    [Travel, Airlines and Aviation Services]
# 2020-05-12    [Food and Drink, Restaurants, Fast Food]
# 2020-05-12  [Food and Drink, Restaurants, Coffee Shop]
# 2020-05-11               [Food and Drink, Restaurants]
# 2020-05-10                          [Transfer, Credit]
# 2020-04-30    [Travel, Airlines and Aviation Services]
# 2020-04-28                              [Travel, Taxi]
# 2020-04-25               [Food and Drink, Restaurants]
# 2020-04-24                                   [Payment]
# 2020-04-24    [Food and Drink, Restaurants, Fast Food]
# 2020-04-24                     [Shops, Sporting Goods]
# 2020-04-15                      [Payment, Credit Card]
# 2020-04-15                              [Travel, Taxi]
# 2020-04-14                           [Transfer, Debit]
# 2020-04-14                         [Transfer, Deposit]
# 2020-04-13      [Recreation, Gyms and Fitness Centers]
# 2020-04-13    [Travel, Airlines and Aviation Services]
# 2020-04-12    [Food and Drink, Restaurants, Fast Food]
# 2020-04-12  [Food and Drink, Restaurants, Coffee Shop]
# 2020-04-11               [Food and Drink, Restaurants]
# 2020-04-10                          [Transfer, Credit]

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
#
# 1. Determine the previous year's gross income and print the results
#
# 2. Determine the current monthly income and print the results
#
# 3. Determine the projected yearly income and print the results

# %%
# Fetch de income data
income_response = client.Income.get(access_token)
# Print the income data
pretty_print_response(income_response)
# Out:
# {
#     "income": {
#         "income_streams": [
#             {
#                 "confidence": 0.99,
#                 "days": 690,
#                 "monthly_income": 500,
#                 "name": "UNITED AIRLINES"
#             }
#         ],
#         "last_year_income": 6000,
#         "last_year_income_before_tax": 7285,
#         "max_number_of_overlapping_income_streams": 1,
#         "number_of_income_streams": 1,
#         "projected_yearly_income": 6085,
#         "projected_yearly_income_before_tax": 7389
#     },
#     "request_id": "QCmflBFHd5P94oO"
# }

# %%
# Determine the previous year's gross income and print the results
previous_yr_gross = income_response['income']['last_year_income']
print(f"The previous year'ss gross income is: {previous_yr_gross}")
# Out:
# The previous year'ss gross income is: 6000

# %%
# Determine the current monthly income and print the results
current_monthly_income = income_response['income']['income_streams'][0]['monthly_income']
print(f"The current monthly income is: {current_monthly_income}")
# Out:
# The current monthly income is: 500

# %%
# Determine the projected yearly income and print the results
projected_yr_income = income_response['income']['projected_yearly_income']
print(f"The projected yearly income is: {projected_yr_income}")
# Out:
# The projected yearly income is: 6085

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
#
# 2. Generate a bar chart with the number of transactions for each category
#
# 3. Calulate the expenses per month
#
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
arr = selected_df['category'].values
lst = [item[0] for item in arr]

# %%
selected_df['category'] = lst
selected_df
# Out:
# /Users/liwei2/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              name   amount        category
# date
# 2020-06-29                        United Airlines   500.00          Travel
# 2020-06-27                 Uber 072515 SF**POOL**     6.33          Travel
# 2020-06-24                             Tectra Inc   500.00  Food and Drink
# 2020-06-23              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-06-23                                    KFC   500.00  Food and Drink
# 2020-06-23                   Madison Bicycle Shop   500.00           Shops
# 2020-06-14           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 2020-06-14                 Uber 063015 SF**POOL**     5.40          Travel
# 2020-06-13  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 2020-06-13                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 2020-06-12                    Touchstone Climbing    78.50      Recreation
# 2020-06-12                        United Airlines  -500.00          Travel
# 2020-06-11                             McDonald's    12.00  Food and Drink
# 2020-06-11                              Starbucks     4.33  Food and Drink
# 2020-06-10                               SparkFun    89.40  Food and Drink
# 2020-06-09                           INTRST PYMNT    -4.22        Transfer
# 2020-05-30                        United Airlines   500.00          Travel
# 2020-05-28                 Uber 072515 SF**POOL**     6.33          Travel
# 2020-05-25                             Tectra Inc   500.00  Food and Drink
# 2020-05-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-05-24                                    KFC   500.00  Food and Drink
# 2020-05-24                   Madison Bicycle Shop   500.00           Shops
# 2020-05-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 2020-05-15                 Uber 063015 SF**POOL**     5.40          Travel
# 2020-05-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 2020-05-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 2020-05-13                    Touchstone Climbing    78.50      Recreation
# 2020-05-13                        United Airlines  -500.00          Travel
# 2020-05-12                             McDonald's    12.00  Food and Drink
# 2020-05-12                              Starbucks     4.33  Food and Drink
# 2020-05-11                               SparkFun    89.40  Food and Drink
# 2020-05-10                           INTRST PYMNT    -4.22        Transfer
# 2020-04-30                        United Airlines   500.00          Travel
# 2020-04-28                 Uber 072515 SF**POOL**     6.33          Travel
# 2020-04-25                             Tectra Inc   500.00  Food and Drink
# 2020-04-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-04-24                                    KFC   500.00  Food and Drink
# 2020-04-24                   Madison Bicycle Shop   500.00           Shops
# 2020-04-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 2020-04-15                 Uber 063015 SF**POOL**     5.40          Travel
# 2020-04-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 2020-04-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 2020-04-13                    Touchstone Climbing    78.50      Recreation
# 2020-04-13                        United Airlines  -500.00          Travel
# 2020-04-12                             McDonald's    12.00  Food and Drink
# 2020-04-12                              Starbucks     4.33  Food and Drink
# 2020-04-11                               SparkFun    89.40  Food and Drink
# 2020-04-10                           INTRST PYMNT    -4.22        Transfer

# %%
# Compute the total expenses per category
selected_df['category'] = lst
cat_expense_df = selected_df.groupby('category').sum()
# Display the expenses per catefory
cat_expense_df
# Out:
# /Users/liwei2/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                   amount
# category
# Food and Drink   3317.19
# Payment          6310.50
# Recreation        235.50
# Shops            1500.00
# Transfer        20537.34
# Travel             35.19

# %%
cat_expense_s = cat_expense_df['amount']

# %%
# Create a spending categories pie chart.
cat_expense_s.plot(kind='pie')

# %% [markdown]
# ### Calculate the expenses per month

# %%
# Create a DataFrame with the total expenses
total_df = selected_df[['amount']]
# Display sample data
total_df
# Out:
#              amount
# date
# 2020-06-29   500.00
# 2020-06-27     6.33
# 2020-06-24   500.00
# 2020-06-23  2078.50
# 2020-06-23   500.00
# 2020-06-23   500.00
# 2020-06-14    25.00
# 2020-06-14     5.40
# 2020-06-13  5850.00
# 2020-06-13  1000.00
# 2020-06-12    78.50
# 2020-06-12  -500.00
# 2020-06-11    12.00
# 2020-06-11     4.33
# 2020-06-10    89.40
# 2020-06-09    -4.22
# 2020-05-30   500.00
# 2020-05-28     6.33
# 2020-05-25   500.00
# 2020-05-24  2078.50
# 2020-05-24   500.00
# 2020-05-24   500.00
# 2020-05-15    25.00
# 2020-05-15     5.40
# 2020-05-14  5850.00
# 2020-05-14  1000.00
# 2020-05-13    78.50
# 2020-05-13  -500.00
# 2020-05-12    12.00
# 2020-05-12     4.33
# 2020-05-11    89.40
# 2020-05-10    -4.22
# 2020-04-30   500.00
# 2020-04-28     6.33
# 2020-04-25   500.00
# 2020-04-24  2078.50
# 2020-04-24   500.00
# 2020-04-24   500.00
# 2020-04-15    25.00
# 2020-04-15     5.40
# 2020-04-14  5850.00
# 2020-04-14  1000.00
# 2020-04-13    78.50
# 2020-04-13  -500.00
# 2020-04-12    12.00
# 2020-04-12     4.33
# 2020-04-11    89.40
# 2020-04-10    -4.22

# %%
# Create a spending per month bar chart
month_spend_grp = total_df.groupby([total_df.index.year, total_df.index.month]).sum()

# %%
month_spend_grp
# Out:
#              amount
# date date
# 2020 4     10645.24
#      5     10645.24
#      6     10645.24

# %%
ax = month_spend_grp.plot(kind = 'bar', title = 'Spending per month')
ax.set_xlabel('Month')
ax.set_ylabel('Amount')
# Out:
# Text(0, 0.5, 'Amount')
